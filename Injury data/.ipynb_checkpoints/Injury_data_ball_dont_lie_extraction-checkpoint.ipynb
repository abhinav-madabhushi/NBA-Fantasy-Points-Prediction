# %%
import requests
import pandas as pd
import time

API_KEY = "YOUR_API_KEY"

# Base URL
base_url = "https://api.balldontlie.io/v1/player_injuries"
headers = {
    "Authorization": f"a06fc0a0-aa21-40a5-8abf-476308868dc9"
}

# Parameters
per_page = 100  # max allowed
page = 1
all_data = []

while True:
    response = requests.get(base_url, params={"page": page, "per_page": per_page}, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}. Status code: {response.status_code}")
        break

    data = response.json()
    injuries = data.get("data", [])

    if not injuries:
        break  # no more data

    all_data.extend(injuries)
    print(f"Fetched page {page} with {len(injuries)} records.")
    page += 1
    time.sleep(0.25)  # avoid overloading the API

# Convert to DataFrame
injuries_df = pd.json_normalize(all_data)

# Display the top rows
print(injuries_df.head())
# Out:
# Fetched page 1 with 100 records.
# Fetched page 2 with 100 records.
# Fetched page 3 with 100 records.
# Fetched page 4 with 100 records.
# Fetched page 5 with 100 records.
# Fetched page 6 with 100 records.
# Fetched page 7 with 100 records.
# Fetched page 8 with 100 records.
# Fetched page 9 with 100 records.
# Fetched page 10 with 100 records.
# Fetched page 11 with 100 records.
# Fetched page 12 with 100 records.
# Fetched page 13 with 100 records.
# Fetched page 14 with 100 records.
# Fetched page 15 with 100 records.
# Exception ignored in: <finalize object at 0x11fc67240; dead>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/weakref.py", line 590, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py", line 1180, in _close_pool_connections
#     conn.close()
#   File "/opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py", line 318, in close
#     super().close()
#   File "/opt/anaconda3/lib/python3.12/http/client.py", line 1020, in close
#     sock.close()   # close it manually... there may be other refs
#     ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/socket.py", line 501, in close
#     def close(self):
#
# KeyboardInterrupt:
# Fetched page 16 with 100 records.
# Fetched page 17 with 100 records.
# Fetched page 18 with 100 records.
# Fetched page 19 with 100 records.
# Fetched page 20 with 100 records.
# Fetched page 21 with 100 records.
# Fetched page 22 with 100 records.
# Fetched page 23 with 100 records.
# Fetched page 24 with 100 records.
# Fetched page 25 with 100 records.
# Fetched page 26 with 100 records.
# Fetched page 27 with 100 records.
# Fetched page 28 with 100 records.
# Fetched page 29 with 100 records.
# Fetched page 30 with 100 records.
# Fetched page 31 with 100 records.
# Fetched page 32 with 100 records.
# Fetched page 33 with 100 records.
# Fetched page 34 with 100 records.
# Fetched page 35 with 100 records.
# Fetched page 36 with 100 records.
# KeyboardInterrupt

# %%
all_data
# Out:
# [{'player': {'id': 83,
#    'first_name': 'Clint',
#    'last_name': 'Capela',
#    'position': 'C',
#    'height': '6-10',
#    'weight': '256',
#    'jersey_number': '15',
#    'college': 'Elan Chalon',
#    'country': 'Switzerland',
#    'draft_year': 2014,
#    'draft_round': 1,
#    'draft_number': 25,
#    'team_id': 1},
#   'return_date': 'Oct 1',
#   'description': "Apr 17: Capela (hand) won't play in Friday's Play-In Game versus the Heat, Brad Rowland of the Locked On Podcast Network reports.",
#   'status': 'Out'},
#  {'player': {'id': 340,
#    'first_name': 'Larry',
#    'last_name': 'Nance Jr.',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '245',
#    'jersey_number': '22',
#    'college': 'Wyoming',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 1,
#    'draft_number': 27,
#    'team_id': 1},
#   'return_date': 'Oct 1',
#   'description': 'Mar 26: The Hawks announced Wednesday that Nance (knee) will miss the rest of the season while recovering from a right medial femoral condyle fracture.',
#   'status': 'Out'},
#  {'player': {'id': 17896040,
#    'first_name': 'Jalen',
#    'last_name': 'Johnson',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '219',
#    'jersey_number': '1',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 20,
#    'team_id': 1},
#   'return_date': 'Oct 1',
#   'description': 'Jan 29: Johnson has suffered a torn labrum in his left shoulder and will miss the rest of the 2024-25 season, NBA reporter Chris Haynes announced Wednesday.',
#   'status': 'Out'},
#  {'player': {'id': 56677838,
#    'first_name': 'Kobe',
#    'last_name': 'Bufkin',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '195',
#    'jersey_number': '4',
#    'college': 'Michigan',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 15,
#    'team_id': 1},
#   'return_date': 'Oct 1',
#   'description': 'Dec 18: Bufkin will miss the remainder of the 2024-25 season as he undergoes surgery to address his right shoulder instability, Michael Scotto of USA Today reports.',
#   'status': 'Out'},
#  {'player': {'id': 17896060,
#    'first_name': 'Sam',
#    'last_name': 'Hauser',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '217',
#    'jersey_number': '30',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 2},
#   'return_date': 'May 10',
#   'description': "May 9: Hauser (ankle) is listed as doubtful for Saturday's game versus the Knicks.",
#   'status': 'Day-To-Day'},
#  {'player': {'id': 17896027,
#    'first_name': 'Ziaire',
#    'last_name': 'Williams',
#    'position': 'G-F',
#    'height': '6-9',
#    'weight': '185',
#    'jersey_number': '8',
#    'college': 'Stanford',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 10,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Williams (knee) has been ruled out for Sunday's game against New York, Sharif Phillips-Keaton of USA Today reports.",
#   'status': 'Out'},
#  {'player': {'id': 1028203324,
#    'first_name': 'Reece',
#    'last_name': 'Beekman',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '190',
#    'jersey_number': '4',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Beekman (calf) has been ruled out for Sunday's game against the Knicks, Sharif Phillips-Keaton of USA Today reports.",
#   'status': 'Out'},
#  {'player': {'id': 666679,
#    'first_name': 'Cameron',
#    'last_name': 'Johnson',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '210',
#    'jersey_number': '2',
#    'college': 'North Carolina',
#    'country': 'USA',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 11,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Johnson (back) has been ruled out for Sunday's game against the Knicks, Brian Lewis of the New York Post reports.",
#   'status': 'Out'},
#  {'player': {'id': 405,
#    'first_name': "D'Angelo",
#    'last_name': 'Russell',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '193',
#    'jersey_number': '1',
#    'college': 'Ohio State',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Russell (ankle) has been ruled out for Sunday's game against New York, Brian Lewis of the New York Post reports.",
#   'status': 'Out'},
#  {'player': {'id': 17896038,
#    'first_name': "Day'Ron",
#    'last_name': 'Sharpe',
#    'position': 'C',
#    'height': '6-9',
#    'weight': '265',
#    'jersey_number': '20',
#    'college': 'North Carolina',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 29,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Sharpe (knee) has been ruled out for Sunday's regular-season finale against the Knicks, Brian Lewis of the New York Post reports.",
#   'status': 'Out'},
#  {'player': {'id': 56677843,
#    'first_name': 'Noah',
#    'last_name': 'Clowney',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '210',
#    'jersey_number': '21',
#    'college': 'Alabama',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 21,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': 'Apr 2: Nets coach Jordi Fernandez said Wednesday that Clowney (ankle) will miss the remainder of the 2024-25 regular season, C.J. Holmes of the New York Daily News reports.',
#   'status': 'Out'},
#  {'player': {'id': 17896048,
#    'first_name': 'Cam',
#    'last_name': 'Thomas',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '210',
#    'jersey_number': '24',
#    'college': 'Louisiana State',
#    'country': 'Japan',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 27,
#    'team_id': 3},
#   'return_date': 'Oct 1',
#   'description': 'Mar 15: The Nets announced Saturday that Thomas has been diagnosed with a left hamstring and is expected to miss the remainder of 2024-25 campaign.',
#   'status': 'Out'},
#  {'player': {'id': 3547274,
#    'first_name': 'Tre',
#    'last_name': 'Jones',
#    'position': 'G',
#    'height': '6-1',
#    'weight': '185',
#    'jersey_number': '30',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 2,
#    'draft_number': 41,
#    'team_id': 5},
#   'return_date': 'Oct 1',
#   'description': "Apr 18: Bulls head coach Billy Donovan said prior to Wednesday's 109-90 loss to the Heat in the Eastern Conference Play-In Tournament that Jones (foot) is no longer using a walking boot, Jared Weiss of The Athletic reports.",
#   'status': 'Out'},
#  {'player': {'id': 27,
#    'first_name': 'Lonzo',
#    'last_name': 'Ball',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '190',
#    'jersey_number': '2',
#    'college': 'UCLA',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 5},
#   'return_date': 'Oct 1',
#   'description': "Apr 18: Ball said Thursday that he won't require surgery on his sprained right wrist and expects to have a normal offseason, K.C. Johnson of Chicago Sports Network reports.",
#   'status': 'Out'},
#  {'player': {'id': 17895983,
#    'first_name': 'Ayo',
#    'last_name': 'Dosunmu',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '200',
#    'jersey_number': '11',
#    'college': 'Illinois',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 2,
#    'draft_number': 38,
#    'team_id': 5},
#   'return_date': 'Oct 1',
#   'description': 'Apr 17: Dosunmu (shoulder) said Thursday that he is no longer wearing a brace and expects to resume 5-on-5 practice in August, K.C. Johnson of Chicago Sports Networkreports.',
#   'status': 'Out'},
#  {'player': {'id': 228,
#    'first_name': 'Kyrie',
#    'last_name': 'Irving',
#    'position': 'G',
#    'height': '6-2',
#    'weight': '195',
#    'jersey_number': '11',
#    'college': 'Duke',
#    'country': 'Australia',
#    'draft_year': 2011,
#    'draft_round': 1,
#    'draft_number': 1,
#    'team_id': 7},
#   'return_date': 'Jan 1',
#   'description': 'Apr 16: The Mavericks are optimistic that Irving (knee) could return by the start of January, Shams Charania of ESPN reports.',
#   'status': 'Out'},
#  {'player': {'id': 56677859,
#    'first_name': 'Olivier-Maxence',
#    'last_name': 'Prosper',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '230',
#    'jersey_number': '8',
#    'college': 'Marquette',
#    'country': 'Canada',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 24,
#    'team_id': 7},
#   'return_date': 'Oct 1',
#   'description': 'Mar 13: Prosper has been ruled out for the remainder of the 2024-25 season after undergoing surgery to repair a right wrist injury.',
#   'status': 'Out'},
#  {'player': {'id': 1028026514,
#    'first_name': 'DaRon',
#    'last_name': 'Holmes II',
#    'position': 'F',
#    'height': '6-10',
#    'weight': '225',
#    'jersey_number': '14',
#    'college': 'Dayton',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 22,
#    'team_id': 8},
#   'return_date': 'Jul 2',
#   'description': "Feb 23: Nuggets head coach Michael Malone said that Holmes (Achilles) was able to participate in portions of Wednesday's practice, Brendan Vogt of TheDNVR.com reports.",
#   'status': 'Out'},
#  {'player': {'id': 3547267,
#    'first_name': 'Isaiah',
#    'last_name': 'Stewart',
#    'position': 'F-C',
#    'height': '6-8',
#    'weight': '250',
#    'jersey_number': '28',
#    'college': 'Washington',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 16,
#    'team_id': 9},
#   'return_date': 'Oct 1',
#   'description': "May 2: Stewart (knee) didn't play in the Pistons' final five games of their first-round playoff matchup with the Knicks.",
#   'status': 'Out'},
#  {'player': {'id': 38017682,
#    'first_name': 'Jaden',
#    'last_name': 'Ivey',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '195',
#    'jersey_number': '23',
#    'college': 'Purdue',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 5,
#    'team_id': 9},
#   'return_date': 'Oct 1',
#   'description': "May 2: Ivey (lower leg) didn't play in the Pistons' final 55 games of the 2024-25 season, including the playoffs.",
#   'status': 'Out'},
#  {'player': {'id': 115,
#    'first_name': 'Stephen',
#    'last_name': 'Curry',
#    'position': 'G',
#    'height': '6-2',
#    'weight': '185',
#    'jersey_number': '30',
#    'college': 'Davidson',
#    'country': 'USA',
#    'draft_year': 2009,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 10},
#   'return_date': 'May 14',
#   'description': 'May 7: The Warriors announced Wednesday that Curry will be re-evaluated in one week.',
#   'status': 'Out'},
#  {'player': {'id': 19465326,
#    'first_name': 'Jock',
#    'last_name': 'Landale',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '255',
#    'jersey_number': '2',
#    'college': "St. Mary's",
#    'country': 'Australia',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 11},
#   'return_date': 'Oct 1',
#   'description': 'May 3: Landale (knee) is out for Game 7 against the Warriors on Sunday.',
#   'status': 'Out'},
#  {'player': {'id': 3547301,
#    'first_name': "Jae'Sean",
#    'last_name': 'Tate',
#    'position': 'F',
#    'height': '6-4',
#    'weight': '230',
#    'jersey_number': '8',
#    'college': 'Ohio State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 11},
#   'return_date': 'Oct 1',
#   'description': 'May 3: Tate (ankle) has been ruled out for Game 7 of the first round of the Western Conference playoffs against the Warriors on Sunday.',
#   'status': 'Out'},
#  {'player': {'id': 17896035,
#    'first_name': 'Isaiah',
#    'last_name': 'Jackson',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '205',
#    'jersey_number': '22',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 22,
#    'team_id': 12},
#   'return_date': 'Oct 1',
#   'description': "Nov 2: Jackson suffered a torn Achilles during Friday's game against the Pelicans, Shams Charania of ESPN reports.",
#   'status': 'Out'},
#  {'player': {'id': 56677855,
#    'first_name': 'Seth',
#    'last_name': 'Lundy',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '220',
#    'jersey_number': '5',
#    'college': 'Penn State',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 2,
#    'draft_number': 46,
#    'team_id': 13},
#   'return_date': 'Jul 2',
#   'description': "Apr 3: Lundy (ankle) isn't listed on the injury report for Friday's game against Dallas.",
#   'status': 'Out'},
#  {'player': {'id': 666786,
#    'first_name': 'Ja',
#    'last_name': 'Morant',
#    'position': 'G',
#    'height': '6-2',
#    'weight': '174',
#    'jersey_number': '12',
#    'college': 'Murray State',
#    'country': 'USA',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 15},
#   'return_date': 'Oct 1',
#   'description': 'Apr 27: Morant (hip) finished the 2024-25 campaign with averages of 23.2 points, 7.3 assists, 4.1 rebounds and 1.2 steals across 30.4 minutes per game in 50 regular-season appearances.',
#   'status': 'Out'},
#  {'player': {'id': 1028112004,
#    'first_name': 'Zyon',
#    'last_name': 'Pullin',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '206',
#    'jersey_number': None,
#    'college': 'Florida',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 15},
#   'return_date': 'Jul 2',
#   'description': "Apr 12: Pullin (knee) has been ruled out for Sunday's game against Dallas.",
#   'status': 'Out'},
#  {'player': {'id': 1028039105,
#    'first_name': 'Jaylen',
#    'last_name': 'Wells',
#    'position': 'F',
#    'height': '6-8',
#    'weight': None,
#    'jersey_number': '0',
#    'college': 'Washington State',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 2,
#    'draft_number': 39,
#    'team_id': 15},
#   'return_date': 'Oct 1',
#   'description': 'Apr 11: Wells (wrist, concussion) has been ruled out for the remainder of the season, Will Guillory of The Athletic reports.',
#   'status': 'Out'},
#  {'player': {'id': 666505,
#    'first_name': 'Brandon',
#    'last_name': 'Clarke',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '215',
#    'jersey_number': '15',
#    'college': 'Gonzaga',
#    'country': 'Canada',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 21,
#    'team_id': 15},
#   'return_date': 'Oct 1',
#   'description': 'Mar 31: Clarke received an orthobiologic injection in his right knee Monday, but he will not require surgery and is expected to make a full recovery prior to the 2025-26 regular season.',
#   'status': 'Out'},
#  {'player': {'id': 403,
#    'first_name': 'Terry',
#    'last_name': 'Rozier',
#    'position': 'G',
#    'height': '6-1',
#    'weight': '190',
#    'jersey_number': '2',
#    'college': 'Louisville',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 1,
#    'draft_number': 16,
#    'team_id': 16},
#   'return_date': 'Oct 1',
#   'description': "Apr 27: Rozier (ankle) has been ruled out for Monday's Game 4 against Cleveland.",
#   'status': 'Out'},
#  {'player': {'id': 1028242168,
#    'first_name': 'Isaiah',
#    'last_name': 'Stevens',
#    'position': 'G',
#    'height': '6-0',
#    'weight': '185',
#    'jersey_number': None,
#    'college': 'Colorado State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 16},
#   'return_date': 'Jul 2',
#   'description': "Apr 17: Stevens is ineligible for the NBA Playoffs, as he's on a two-way contract.",
#   'status': 'Out'},
#  {'player': {'id': 1028038570,
#    'first_name': 'Tyler',
#    'last_name': 'Smith',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '224',
#    'jersey_number': '21',
#    'college': 'NBA G League Ignite',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 2,
#    'draft_number': 33,
#    'team_id': 17},
#   'return_date': 'Jul 2',
#   'description': "Apr 29: Smith (ankle) has been ruled out for Tuesday's Game 5 against the Pacers.",
#   'status': 'Out'},
#  {'player': {'id': 278,
#    'first_name': 'Damian',
#    'last_name': 'Lillard',
#    'position': 'G',
#    'height': '6-2',
#    'weight': '195',
#    'jersey_number': '0',
#    'college': 'Weber State',
#    'country': 'USA',
#    'draft_year': 2012,
#    'draft_round': 1,
#    'draft_number': 6,
#    'team_id': 17},
#   'return_date': 'Mar 1',
#   'description': 'Apr 28: Lillard has been diagnosed with a left torn Achilles tendon, NBA reporter Chris Haynes reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028025639,
#    'first_name': 'Rob',
#    'last_name': 'Dillingham',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '175',
#    'jersey_number': '4',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 8,
#    'team_id': 18},
#   'return_date': 'May 10',
#   'description': "May 8: Dillingham (ankle) won't play in Thursday's Game 2 versus the Warriors.",
#   'status': 'Out'},
#  {'player': {'id': 358,
#    'first_name': 'Kelly',
#    'last_name': 'Olynyk',
#    'position': 'F',
#    'height': '6-11',
#    'weight': '240',
#    'jersey_number': '13',
#    'college': 'Gonzaga',
#    'country': 'Canada',
#    'draft_year': 2013,
#    'draft_round': 1,
#    'draft_number': 13,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': 'Apr 28: The Pelicans announced Monday that Olynyk recently underwent a minimally invasive surgery on his left heel and ultrasound guided tendon debridement.',
#   'status': 'Out'},
#  {'player': {'id': 69,
#    'first_name': 'Bruce',
#    'last_name': 'Brown',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '202',
#    'jersey_number': '00',
#    'college': 'Miami',
#    'country': 'USA',
#    'draft_year': 2018,
#    'draft_round': 2,
#    'draft_number': 42,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Brown (knee) is out for Sunday's game against the Thunder.",
#   'status': 'Out'},
#  {'player': {'id': 1028245777,
#    'first_name': 'Karlo',
#    'last_name': 'Matkovic',
#    'position': 'F-C',
#    'height': '6-10',
#    'weight': '231',
#    'jersey_number': '17',
#    'college': 'Mega Basket',
#    'country': 'Bosnia and Herzegovina',
#    'draft_year': 2022,
#    'draft_round': 2,
#    'draft_number': 52,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Matkovic (hamstring) has been ruled out for Sunday's game against the Thunder.",
#   'status': 'Out'},
#  {'player': {'id': 56677837,
#    'first_name': 'Jordan',
#    'last_name': 'Hawkins',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '190',
#    'jersey_number': '24',
#    'college': 'Connecticut',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 14,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Hawkins (back) is out for Sunday's game against the Thunder.",
#   'status': 'Out'},
#  {'player': {'id': 1028027567,
#    'first_name': 'Yves',
#    'last_name': 'Missi',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '235',
#    'jersey_number': '21',
#    'college': 'Baylor',
#    'country': 'Cameroon',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 21,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Missi (ankle) is out for Sunday's game against the Thunder.",
#   'status': 'Out'},
#  {'player': {'id': 303,
#    'first_name': 'CJ',
#    'last_name': 'McCollum',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '190',
#    'jersey_number': '3',
#    'college': 'Lehigh',
#    'country': 'USA',
#    'draft_year': 2013,
#    'draft_round': 1,
#    'draft_number': 10,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': 'Mar 31: The Pelicans announced Monday that McCollum (foot) will miss the remainder of the 2024-25 season.',
#   'status': 'Out'},
#  {'player': {'id': 666969,
#    'first_name': 'Zion',
#    'last_name': 'Williamson',
#    'position': 'F',
#    'height': '6-6',
#    'weight': '284',
#    'jersey_number': '1',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 1,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Mar 31: The Pelicans announced Monday that Williamson (back) won't play for the rest of the 2024-25 season.",
#   'status': 'Out'},
#  {'player': {'id': 18677986,
#    'first_name': 'Trey',
#    'last_name': 'Murphy III',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '206',
#    'jersey_number': '25',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 17,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Mar 18: Murphy sustained a season-ending torn labrum in his right shoulder during Monday's 127-81 loss to the Pistons, Shams Charania of ESPN reports.",
#   'status': 'Out'},
#  {'player': {'id': 17896024,
#    'first_name': 'Herbert',
#    'last_name': 'Jones',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '206',
#    'jersey_number': '2',
#    'college': 'Alabama',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 2,
#    'draft_number': 35,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': 'Feb 26: The Pelicans announced that Jones underwent successful surgery Feb. 12 to repair a torn rotator cuff in his right shoulder.',
#   'status': 'Out'},
#  {'player': {'id': 334,
#    'first_name': 'Dejounte',
#    'last_name': 'Murray',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '180',
#    'jersey_number': '5',
#    'college': 'Washington',
#    'country': 'USA',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 29,
#    'team_id': 19},
#   'return_date': 'Oct 1',
#   'description': "Jan 31: Shams Charania of ESPNMurray suffered a torn right Achilles tendon during Friday's game against the Celtics and will now miss the rest of the season, Shams Charania of ESPN.com reports.",
#   'status': 'Out'},
#  {'player': {'id': 1028028932,
#    'first_name': 'Nikola',
#    'last_name': 'Topic',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '200',
#    'jersey_number': '44',
#    'college': 'Crvena zvezda',
#    'country': 'Serbia',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 12,
#    'team_id': 21},
#   'return_date': 'Jul 2',
#   'description': "Jan 12: Topic (knee) was spotted taking part in light shooting drills on the court prior to the Thunder's 105-92 loss to the Celtics last Sunday, Clemente Almanza of USA Today reports.",
#   'status': 'Out'},
#  {'player': {'id': 17896073,
#    'first_name': 'Jalen',
#    'last_name': 'Suggs',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '205',
#    'jersey_number': '4',
#    'college': 'Gonzaga',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 5,
#    'team_id': 22},
#   'return_date': 'Oct 1',
#   'description': 'Mar 4: The Magic announced Tuesday that Suggs (knee) has been ruled out for the remainder of the 2024-25 campaign after undergoing successful surgery.',
#   'status': 'Out'},
#  {'player': {'id': 462,
#    'first_name': 'Moritz',
#    'last_name': 'Wagner',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '245',
#    'jersey_number': '21',
#    'college': 'Michigan',
#    'country': 'Germany',
#    'draft_year': 2018,
#    'draft_round': 1,
#    'draft_number': 25,
#    'team_id': 22},
#   'return_date': 'Oct 1',
#   'description': 'Jan 9: The Magic announced that Wagner underwent successful surgery to repair a torn ACL in his left knee Wednesday and will miss the remainder of the 2024-25 season.',
#   'status': 'Out'},
#  {'player': {'id': 488,
#    'first_name': 'Guerschon',
#    'last_name': 'Yabusele',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '265',
#    'jersey_number': '28',
#    'college': 'Rouen, France',
#    'country': 'France',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 16,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Yabusele (knee) has been ruled out for Sunday's game against the Bulls, Adam Aaronson of PhillyVoice.com reports.",
#   'status': 'Out'},
#  {'player': {'id': 1028214238,
#    'first_name': 'Justin',
#    'last_name': 'Edwards',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '203',
#    'jersey_number': '19',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Edwards (ribs) has been ruled out for Sunday's game against the Bulls, Adam Aaronson of PhillyVoice.comreports.",
#   'status': 'Out'},
#  {'player': {'id': 286,
#    'first_name': 'Kyle',
#    'last_name': 'Lowry',
#    'position': 'G',
#    'height': '6-0',
#    'weight': '196',
#    'jersey_number': '7',
#    'college': 'Villanova',
#    'country': 'USA',
#    'draft_year': 2006,
#    'draft_round': 1,
#    'draft_number': 24,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Lowry (hip) is out for Sunday's game against the Bulls.",
#   'status': 'Out'},
#  {'player': {'id': 137,
#    'first_name': 'Andre',
#    'last_name': 'Drummond',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '279',
#    'jersey_number': '1',
#    'college': 'Connecticut',
#    'country': 'USA',
#    'draft_year': 2012,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Drummond (toe) has been ruled out for Sunday's game against Chicago.",
#   'status': 'Out'},
#  {'player': {'id': 145,
#    'first_name': 'Joel',
#    'last_name': 'Embiid',
#    'position': 'F-C',
#    'height': '7-0',
#    'weight': '280',
#    'jersey_number': '21',
#    'college': 'Kansas',
#    'country': 'Cameroon',
#    'draft_year': 2014,
#    'draft_round': 1,
#    'draft_number': 3,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': 'Apr 11: The 76ers announced Friday that Embiid underwent successful arthroscopic surgery on his left knee Wednesday, and he will be re-evaluated in approximately six weeks, Ky Carlin of USA Today reports.',
#   'status': 'Out'},
#  {'player': {'id': 360,
#    'first_name': 'Kelly',
#    'last_name': 'Oubre Jr.',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '203',
#    'jersey_number': '9',
#    'college': 'Kansas',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 1,
#    'draft_number': 15,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': "Apr 10: Oubre (knee) has been ruled out for Friday's game against the Wizards.",
#   'status': 'Out'},
#  {'player': {'id': 3547254,
#    'first_name': 'Tyrese',
#    'last_name': 'Maxey',
#    'position': 'G',
#    'height': '6-2',
#    'weight': '200',
#    'jersey_number': '0',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 21,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': 'Apr 3: Maxey (finger) is expected to miss the rest of the season, Shams Charania of ESPN reported Thursday.',
#   'status': 'Out'},
#  {'player': {'id': 172,
#    'first_name': 'Paul',
#    'last_name': 'George',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '220',
#    'jersey_number': '8',
#    'college': 'Fresno State',
#    'country': 'USA',
#    'draft_year': 2010,
#    'draft_round': 1,
#    'draft_number': 10,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': 'Mar 17: George received injections in his left adductor muscle and left knee Monday and has been ruled out for the remainder of the season, Shams Charania of ESPN reports.',
#   'status': 'Out'},
#  {'player': {'id': 178,
#    'first_name': 'Eric',
#    'last_name': 'Gordon',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '215',
#    'jersey_number': '23',
#    'college': 'Indiana',
#    'country': 'USA',
#    'draft_year': 2008,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': 'Feb 27: The 76ers announced Thursday that Gordon (wrist) will be re-evaluated in three months after undergoing successful surgery Wednesday, Keith Pompey of The Philadelphia Inquirer reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028027372,
#    'first_name': 'Jared',
#    'last_name': 'McCain',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '195',
#    'jersey_number': '20',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 16,
#    'team_id': 23},
#   'return_date': 'Oct 1',
#   'description': 'Jan 9: McCain was reviewed Thursday by the surgeon who performed surgery on his left knee and is progressing well. The 76ers officially ruled out for the rest of the season, Kyle Neubeck of AllPHLY.com reports.',
#   'status': 'Out'},
#  {'player': {'id': 3547282,
#    'first_name': 'Nick',
#    'last_name': 'Richards',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '245',
#    'jersey_number': '2',
#    'college': 'Kentucky',
#    'country': 'Jamaica',
#    'draft_year': 2020,
#    'draft_round': 2,
#    'draft_number': 42,
#    'team_id': 24},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Richards (elbow) is out for Sunday's game against the Kings.",
#   'status': 'Out'},
#  {'player': {'id': 57,
#    'first_name': 'Devin',
#    'last_name': 'Booker',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '206',
#    'jersey_number': '1',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 1,
#    'draft_number': 13,
#    'team_id': 24},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Booker is out for Sunday's game against the Kings due to right calf soreness.",
#   'status': 'Out'},
#  {'player': {'id': 140,
#    'first_name': 'Kevin',
#    'last_name': 'Durant',
#    'position': 'F',
#    'height': '6-11',
#    'weight': '240',
#    'jersey_number': '35',
#    'college': 'Texas',
#    'country': 'USA',
#    'draft_year': 2007,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 24},
#   'return_date': 'Oct 1',
#   'description': "Apr 11: Head coach Mike Budenholzer said Friday that Durant, who has already been ruled out against the Spurs due to a left ankle sprain, will not play in the Suns' regular-season finale against the Kings on Sunday, Duane Rankin of The Arizona Republic reports.",
#   'status': 'Out'},
#  {'player': {'id': 38017690,
#    'first_name': 'Shaedon',
#    'last_name': 'Sharpe',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '208',
#    'jersey_number': '17',
#    'college': 'Kentucky',
#    'country': 'Canada',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Sharpe (knee) has been ruled out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 3547242,
#    'first_name': 'Deni',
#    'last_name': 'Avdija',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '240',
#    'jersey_number': '8',
#    'college': 'Maccabi Tel Aviv',
#    'country': 'Israel',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Avdija (thumb) has been ruled out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 56677747,
#    'first_name': 'Scoot',
#    'last_name': 'Henderson',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '206',
#    'jersey_number': '00',
#    'college': 'NBA G League Ignite',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 3,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Henderson (concussion) is out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 419,
#    'first_name': 'Anfernee',
#    'last_name': 'Simons',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '200',
#    'jersey_number': '1',
#    'college': 'Edgewater HS (FL)',
#    'country': 'USA',
#    'draft_year': 2018,
#    'draft_round': 1,
#    'draft_number': 24,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Simons (forearm) is out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 22,
#    'first_name': 'Deandre',
#    'last_name': 'Ayton',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '252',
#    'jersey_number': '2',
#    'college': 'Arizona',
#    'country': 'Bahamas',
#    'draft_year': 2018,
#    'draft_round': 1,
#    'draft_number': 1,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Ayton (calf) is out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 182,
#    'first_name': 'Jerami',
#    'last_name': 'Grant',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '210',
#    'jersey_number': '9',
#    'college': 'Syracuse',
#    'country': 'USA',
#    'draft_year': 2014,
#    'draft_round': 2,
#    'draft_number': 39,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Grant (knee) is out for Sunday's game against the Lakers.",
#   'status': 'Out'},
#  {'player': {'id': 38017708,
#    'first_name': 'Bryce',
#    'last_name': 'McGowens',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '190',
#    'jersey_number': '11',
#    'college': 'Nebraska',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 2,
#    'draft_number': 40,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': "Mar 26: McGowens will miss the rest of the regular season after suffering a right rib fracture during Monday's G League game with the Rip City Remix, Sean Highkin of Rip City Radio 620 Portland reports.",
#   'status': 'Out'},
#  {'player': {'id': 476,
#    'first_name': 'Robert',
#    'last_name': 'Williams III',
#    'position': 'C-F',
#    'height': '6-9',
#    'weight': '249',
#    'jersey_number': '35',
#    'college': 'Texas A&M',
#    'country': 'USA',
#    'draft_year': 2018,
#    'draft_round': 1,
#    'draft_number': 27,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': 'Mar 20: Williams underwent an arthroscopic procedure Thursday to address inflammation in his left knee and will miss 4-6 weeks.',
#   'status': 'Out'},
#  {'player': {'id': 38017728,
#    'first_name': 'Jake',
#    'last_name': 'LaRavia',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '235',
#    'jersey_number': '33',
#    'college': 'Wake Forest',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 26},
#   'return_date': 'Oct 1',
#   'description': "Apr 15: LaRavia (thumb) won't play in Wednesday's Play-In Game against the Mavericks.",
#   'status': 'Out'},
#  {'player': {'id': 324,
#    'first_name': 'Malik',
#    'last_name': 'Monk',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '200',
#    'jersey_number': '0',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 11,
#    'team_id': 26},
#   'return_date': 'Oct 1',
#   'description': 'Apr 9: Monk Shams Charania of ESPN for a strained left calf injury in two weeks, Shams Charania reports.',
#   'status': 'Out'},
#  {'player': {'id': 3547246,
#    'first_name': 'Devin',
#    'last_name': 'Vassell',
#    'position': 'G-F',
#    'height': '6-5',
#    'weight': '200',
#    'jersey_number': '24',
#    'college': 'Florida State',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 11,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Vassell (ankle) is out for Sunday's game against the Raptors.",
#   'status': 'Out'},
#  {'player': {'id': 38017699,
#    'first_name': 'Jeremy',
#    'last_name': 'Sochan',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '230',
#    'jersey_number': '10',
#    'college': 'Baylor',
#    'country': 'Poland',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Sochan (back) is out for Sunday's game against the Raptors.",
#   'status': 'Out'},
#  {'player': {'id': 56677822,
#    'first_name': 'Victor',
#    'last_name': 'Wembanyama',
#    'position': 'F-C',
#    'height': '7-3',
#    'weight': '235',
#    'jersey_number': '1',
#    'college': 'Metropolitans 92',
#    'country': 'France',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 1,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': 'Mar 27: Head coach of the French National team, Frederic Fauthoux, said Thursday that Wembanyama underwent surgery on the deep vein thrombosis in his right shoulder and is feeling fine, Jeff Garcia of KENS 5 San Antonio reports.',
#   'status': 'Out'},
#  {'player': {'id': 161,
#    'first_name': "De'Aaron",
#    'last_name': 'Fox',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '185',
#    'jersey_number': '4',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 5,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': 'Mar 13: Fox will undergo season-ending surgery to repair tendon damage in his left pinkie finger Tuesday, Shams Charania of ESPN reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028245994,
#    'first_name': 'Riley',
#    'last_name': 'Minix',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '230',
#    'jersey_number': '27',
#    'college': 'Morehead State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 27},
#   'return_date': 'Jul 1',
#   'description': 'Jan 15: Minix will miss the remainder of the season with a torn labrum in his left shoulder, Michael C. Wright of ESPN.com reports.',
#   'status': 'Out'},
#  {'player': {'id': 436,
#    'first_name': 'Garrett',
#    'last_name': 'Temple',
#    'position': 'G-F',
#    'height': '6-5',
#    'weight': '195',
#    'jersey_number': '17',
#    'college': 'Louisiana State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 23: Temple has been ruled out for the rest of Sunday's game against the Spurs due to a left knee sprain, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 42097199,
#    'first_name': 'Jared',
#    'last_name': 'Rhoden',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '210',
#    'jersey_number': '8',
#    'college': 'Seton Hall',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 22: Rhoden underwent surgery this week to repair a torn labrum in his right shoulder and will face a 4-to-6-month recovery, Josh Lewenberg of TSN.ca reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028045145,
#    'first_name': 'Ulrich',
#    'last_name': 'Chomche',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '235',
#    'jersey_number': '22',
#    'college': 'NBA Global Academy',
#    'country': 'Cameroon',
#    'draft_year': 2024,
#    'draft_round': 2,
#    'draft_number': 57,
#    'team_id': 28},
#   'return_date': 'Jul 1',
#   'description': 'Apr 15: Head coach Darko Rajakovic anticipates watching Chomche (knee) play in the Las Vegas Summer League in July, Esfandiar Baraheni of The Athletic reports.',
#   'status': 'Out'},
#  {'player': {'id': 58,
#    'first_name': 'Chris',
#    'last_name': 'Boucher',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '200',
#    'jersey_number': '25',
#    'college': 'Oregon',
#    'country': 'Saint Lucia',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Boucher (illness) has been ruled out for Sunday's game against the Spurs, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 1028029111,
#    'first_name': "Ja'Kobe",
#    'last_name': 'Walter',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '180',
#    'jersey_number': '14',
#    'college': 'Baylor',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Walter (hip) is out for Sunday's game against the Spurs, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 373,
#    'first_name': 'Jakob',
#    'last_name': 'Poeltl',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '260',
#    'jersey_number': '19',
#    'college': 'Utah',
#    'country': 'Austria',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Poeltl (hand) has been ruled out for Sunday's game against San Antonio, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 227,
#    'first_name': 'Brandon',
#    'last_name': 'Ingram',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '190',
#    'jersey_number': '3',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 9: The Raptors officially shut down Ingram for the rest of the season Wednesday after he got a PRP injection in his left ankle, Michael Grange of Sportsnet.ca reports.',
#   'status': 'Out'},
#  {'player': {'id': 56677828,
#    'first_name': 'Gradey',
#    'last_name': 'Dick',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '200',
#    'jersey_number': '1',
#    'college': 'Kansas',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 13,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 4: Dick (knee) is out for the remainder of the 2024-25 regular season, Ryan Wolstat of the Toronto Sun reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028264794,
#    'first_name': 'Elijah',
#    'last_name': 'Harkless',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '195',
#    'jersey_number': '16',
#    'college': 'UNLV',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 29},
#   'return_date': 'Jul 1',
#   'description': "Apr 12: Harkless (groin) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 101,
#    'first_name': 'John',
#    'last_name': 'Collins',
#    'position': 'F-C',
#    'height': '6-9',
#    'weight': '226',
#    'jersey_number': '20',
#    'college': 'Wake Forest',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Collins (ankle) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 297,
#    'first_name': 'Lauri',
#    'last_name': 'Markkanen',
#    'position': 'F',
#    'height': '7-0',
#    'weight': '240',
#    'jersey_number': '23',
#    'college': 'Arizona',
#    'country': 'Finland',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Markkanen (knee) has been ruled out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 1028025362,
#    'first_name': 'Isaiah',
#    'last_name': 'Collier',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '210',
#    'jersey_number': '13',
#    'college': 'Southern California',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 29,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Collier (hamstring) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 38017705,
#    'first_name': 'Walker',
#    'last_name': 'Kessler',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '245',
#    'jersey_number': '24',
#    'college': 'Auburn',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 22,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Kessler (concussion) has been ruled out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 1028029291,
#    'first_name': 'Cody',
#    'last_name': 'Williams',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '190',
#    'jersey_number': '5',
#    'college': 'Colorado',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 10,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Apr 2: The Jazz announced Wednesday that Williams tested positive for mononucleosis, ruling him out for the remainder of the season, Ben Anderson of KSL News Salt Lake City reports.',
#   'status': 'Out'},
#  {'player': {'id': 100,
#    'first_name': 'Jordan',
#    'last_name': 'Clarkson',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '194',
#    'jersey_number': '00',
#    'college': 'Missouri',
#    'country': 'USA',
#    'draft_year': 2014,
#    'draft_round': 2,
#    'draft_number': 46,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Mar 27: Clarkson will miss the rest of the season for the Jazz after having a procedure to address the plantar fasciitis in his left foot, Mark Medina of TheSportingTribune.comreports.',
#   'status': 'Out'},
#  {'player': {'id': 56677824,
#    'first_name': 'Taylor',
#    'last_name': 'Hendricks',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '215',
#    'jersey_number': '0',
#    'college': 'Central Florida',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Nov 6: Hendricks underwent surgery on his broken right leg and dislocated ankle Wednesday, Andy Larsen of The Salt Lake Tribune reports.',
#   'status': 'Out'},
#  {'player': {'id': 18678001,
#    'first_name': 'JT',
#    'last_name': 'Thor',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '203',
#    'jersey_number': '21',
#    'college': 'Auburn',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 2,
#    'draft_number': 37,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Thor (knee) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 3547256,
#    'first_name': 'Saddiq',
#    'last_name': 'Bey',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '215',
#    'jersey_number': '14',
#    'college': 'Villanova',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Bey (knee) won't play in Sunday's game versus the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 65,
#    'first_name': 'Malcolm',
#    'last_name': 'Brogdon',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '229',
#    'jersey_number': '15',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': 2016,
#    'draft_round': 2,
#    'draft_number': 36,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Brogdon (ankle) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 217,
#    'first_name': 'Richaun',
#    'last_name': 'Holmes',
#    'position': 'F-C',
#    'height': '6-9',
#    'weight': '235',
#    'jersey_number': '22',
#    'college': 'Bowling Green',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 2,
#    'draft_number': 37,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Holmes (shoulder) has been ruled out for Sunday's game against Miami.",
#   'status': 'Out'},
#  {'player': {'id': 666848,
#    'first_name': 'Jordan',
#    'last_name': 'Poole',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '194',
#    'jersey_number': '13',
#    'college': 'Michigan',
#    'country': 'USA',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 28,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Poole (elbow) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 3547302,
#    'first_name': 'Anthony',
#    'last_name': 'Gill',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '230',
#    'jersey_number': '16',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Gill (hamstring) has been ruled out for Sunday's game against Miami.",
#   'status': 'Out'},
#  {'player': {'id': 315,
#    'first_name': 'Khris',
#    'last_name': 'Middleton',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '222',
#    'jersey_number': '32',
#    'college': 'Texas A&M',
#    'country': 'USA',
#    'draft_year': 2012,
#    'draft_round': 2,
#    'draft_number': 39,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': 'Apr 11: Head coach Brian Keefe said Friday that Middleton (knee) is unlikely to return this season, Varun Shankar of The Washington Post reports.',
# ...
#    'last_name': 'Williams III',
#    'position': 'C-F',
#    'height': '6-9',
#    'weight': '249',
#    'jersey_number': '35',
#    'college': 'Texas A&M',
#    'country': 'USA',
#    'draft_year': 2018,
#    'draft_round': 1,
#    'draft_number': 27,
#    'team_id': 25},
#   'return_date': 'Oct 1',
#   'description': 'Mar 20: Williams underwent an arthroscopic procedure Thursday to address inflammation in his left knee and will miss 4-6 weeks.',
#   'status': 'Out'},
#  {'player': {'id': 38017728,
#    'first_name': 'Jake',
#    'last_name': 'LaRavia',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '235',
#    'jersey_number': '33',
#    'college': 'Wake Forest',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 26},
#   'return_date': 'Oct 1',
#   'description': "Apr 15: LaRavia (thumb) won't play in Wednesday's Play-In Game against the Mavericks.",
#   'status': 'Out'},
#  {'player': {'id': 324,
#    'first_name': 'Malik',
#    'last_name': 'Monk',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '200',
#    'jersey_number': '0',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 11,
#    'team_id': 26},
#   'return_date': 'Oct 1',
#   'description': 'Apr 9: Monk Shams Charania of ESPN for a strained left calf injury in two weeks, Shams Charania reports.',
#   'status': 'Out'},
#  {'player': {'id': 3547246,
#    'first_name': 'Devin',
#    'last_name': 'Vassell',
#    'position': 'G-F',
#    'height': '6-5',
#    'weight': '200',
#    'jersey_number': '24',
#    'college': 'Florida State',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 11,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Vassell (ankle) is out for Sunday's game against the Raptors.",
#   'status': 'Out'},
#  {'player': {'id': 38017699,
#    'first_name': 'Jeremy',
#    'last_name': 'Sochan',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '230',
#    'jersey_number': '10',
#    'college': 'Baylor',
#    'country': 'Poland',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Sochan (back) is out for Sunday's game against the Raptors.",
#   'status': 'Out'},
#  {'player': {'id': 56677822,
#    'first_name': 'Victor',
#    'last_name': 'Wembanyama',
#    'position': 'F-C',
#    'height': '7-3',
#    'weight': '235',
#    'jersey_number': '1',
#    'college': 'Metropolitans 92',
#    'country': 'France',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 1,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': 'Mar 27: Head coach of the French National team, Frederic Fauthoux, said Thursday that Wembanyama underwent surgery on the deep vein thrombosis in his right shoulder and is feeling fine, Jeff Garcia of KENS 5 San Antonio reports.',
#   'status': 'Out'},
#  {'player': {'id': 161,
#    'first_name': "De'Aaron",
#    'last_name': 'Fox',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '185',
#    'jersey_number': '4',
#    'college': 'Kentucky',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 5,
#    'team_id': 27},
#   'return_date': 'Oct 1',
#   'description': 'Mar 13: Fox will undergo season-ending surgery to repair tendon damage in his left pinkie finger Tuesday, Shams Charania of ESPN reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028245994,
#    'first_name': 'Riley',
#    'last_name': 'Minix',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '230',
#    'jersey_number': '27',
#    'college': 'Morehead State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 27},
#   'return_date': 'Jul 1',
#   'description': 'Jan 15: Minix will miss the remainder of the season with a torn labrum in his left shoulder, Michael C. Wright of ESPN.com reports.',
#   'status': 'Out'},
#  {'player': {'id': 436,
#    'first_name': 'Garrett',
#    'last_name': 'Temple',
#    'position': 'G-F',
#    'height': '6-5',
#    'weight': '195',
#    'jersey_number': '17',
#    'college': 'Louisiana State',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 23: Temple has been ruled out for the rest of Sunday's game against the Spurs due to a left knee sprain, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 42097199,
#    'first_name': 'Jared',
#    'last_name': 'Rhoden',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '210',
#    'jersey_number': '8',
#    'college': 'Seton Hall',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 22: Rhoden underwent surgery this week to repair a torn labrum in his right shoulder and will face a 4-to-6-month recovery, Josh Lewenberg of TSN.ca reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028045145,
#    'first_name': 'Ulrich',
#    'last_name': 'Chomche',
#    'position': 'C',
#    'height': '6-11',
#    'weight': '235',
#    'jersey_number': '22',
#    'college': 'NBA Global Academy',
#    'country': 'Cameroon',
#    'draft_year': 2024,
#    'draft_round': 2,
#    'draft_number': 57,
#    'team_id': 28},
#   'return_date': 'Jul 1',
#   'description': 'Apr 15: Head coach Darko Rajakovic anticipates watching Chomche (knee) play in the Las Vegas Summer League in July, Esfandiar Baraheni of The Athletic reports.',
#   'status': 'Out'},
#  {'player': {'id': 58,
#    'first_name': 'Chris',
#    'last_name': 'Boucher',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '200',
#    'jersey_number': '25',
#    'college': 'Oregon',
#    'country': 'Saint Lucia',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Boucher (illness) has been ruled out for Sunday's game against the Spurs, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 1028029111,
#    'first_name': "Ja'Kobe",
#    'last_name': 'Walter',
#    'position': 'G',
#    'height': '6-5',
#    'weight': '180',
#    'jersey_number': '14',
#    'college': 'Baylor',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Walter (hip) is out for Sunday's game against the Spurs, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 373,
#    'first_name': 'Jakob',
#    'last_name': 'Poeltl',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '260',
#    'jersey_number': '19',
#    'college': 'Utah',
#    'country': 'Austria',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Poeltl (hand) has been ruled out for Sunday's game against San Antonio, Blake Murphy of Sportsnet.ca reports.",
#   'status': 'Out'},
#  {'player': {'id': 227,
#    'first_name': 'Brandon',
#    'last_name': 'Ingram',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '190',
#    'jersey_number': '3',
#    'college': 'Duke',
#    'country': 'USA',
#    'draft_year': 2016,
#    'draft_round': 1,
#    'draft_number': 2,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 9: The Raptors officially shut down Ingram for the rest of the season Wednesday after he got a PRP injection in his left ankle, Michael Grange of Sportsnet.ca reports.',
#   'status': 'Out'},
#  {'player': {'id': 56677828,
#    'first_name': 'Gradey',
#    'last_name': 'Dick',
#    'position': 'G',
#    'height': '6-6',
#    'weight': '200',
#    'jersey_number': '1',
#    'college': 'Kansas',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 13,
#    'team_id': 28},
#   'return_date': 'Oct 1',
#   'description': 'Apr 4: Dick (knee) is out for the remainder of the 2024-25 regular season, Ryan Wolstat of the Toronto Sun reports.',
#   'status': 'Out'},
#  {'player': {'id': 1028264794,
#    'first_name': 'Elijah',
#    'last_name': 'Harkless',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '195',
#    'jersey_number': '16',
#    'college': 'UNLV',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 29},
#   'return_date': 'Jul 1',
#   'description': "Apr 12: Harkless (groin) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 101,
#    'first_name': 'John',
#    'last_name': 'Collins',
#    'position': 'F-C',
#    'height': '6-9',
#    'weight': '226',
#    'jersey_number': '20',
#    'college': 'Wake Forest',
#    'country': 'USA',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Collins (ankle) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 297,
#    'first_name': 'Lauri',
#    'last_name': 'Markkanen',
#    'position': 'F',
#    'height': '7-0',
#    'weight': '240',
#    'jersey_number': '23',
#    'college': 'Arizona',
#    'country': 'Finland',
#    'draft_year': 2017,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Markkanen (knee) has been ruled out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 1028025362,
#    'first_name': 'Isaiah',
#    'last_name': 'Collier',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '210',
#    'jersey_number': '13',
#    'college': 'Southern California',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 29,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Collier (hamstring) is out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 38017705,
#    'first_name': 'Walker',
#    'last_name': 'Kessler',
#    'position': 'C',
#    'height': '7-0',
#    'weight': '245',
#    'jersey_number': '24',
#    'college': 'Auburn',
#    'country': 'USA',
#    'draft_year': 2022,
#    'draft_round': 1,
#    'draft_number': 22,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Kessler (concussion) has been ruled out for Sunday's game against the Timberwolves.",
#   'status': 'Out'},
#  {'player': {'id': 1028029291,
#    'first_name': 'Cody',
#    'last_name': 'Williams',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '190',
#    'jersey_number': '5',
#    'college': 'Colorado',
#    'country': 'USA',
#    'draft_year': 2024,
#    'draft_round': 1,
#    'draft_number': 10,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Apr 2: The Jazz announced Wednesday that Williams tested positive for mononucleosis, ruling him out for the remainder of the season, Ben Anderson of KSL News Salt Lake City reports.',
#   'status': 'Out'},
#  {'player': {'id': 100,
#    'first_name': 'Jordan',
#    'last_name': 'Clarkson',
#    'position': 'G',
#    'height': '6-3',
#    'weight': '194',
#    'jersey_number': '00',
#    'college': 'Missouri',
#    'country': 'USA',
#    'draft_year': 2014,
#    'draft_round': 2,
#    'draft_number': 46,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Mar 27: Clarkson will miss the rest of the season for the Jazz after having a procedure to address the plantar fasciitis in his left foot, Mark Medina of TheSportingTribune.comreports.',
#   'status': 'Out'},
#  {'player': {'id': 56677824,
#    'first_name': 'Taylor',
#    'last_name': 'Hendricks',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '215',
#    'jersey_number': '0',
#    'college': 'Central Florida',
#    'country': 'USA',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 9,
#    'team_id': 29},
#   'return_date': 'Oct 1',
#   'description': 'Nov 6: Hendricks underwent surgery on his broken right leg and dislocated ankle Wednesday, Andy Larsen of The Salt Lake Tribune reports.',
#   'status': 'Out'},
#  {'player': {'id': 18678001,
#    'first_name': 'JT',
#    'last_name': 'Thor',
#    'position': 'F',
#    'height': '6-9',
#    'weight': '203',
#    'jersey_number': '21',
#    'college': 'Auburn',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 2,
#    'draft_number': 37,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 13: Thor (knee) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 3547256,
#    'first_name': 'Saddiq',
#    'last_name': 'Bey',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '215',
#    'jersey_number': '14',
#    'college': 'Villanova',
#    'country': 'USA',
#    'draft_year': 2020,
#    'draft_round': 1,
#    'draft_number': 19,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Bey (knee) won't play in Sunday's game versus the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 65,
#    'first_name': 'Malcolm',
#    'last_name': 'Brogdon',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '229',
#    'jersey_number': '15',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': 2016,
#    'draft_round': 2,
#    'draft_number': 36,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Brogdon (ankle) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 217,
#    'first_name': 'Richaun',
#    'last_name': 'Holmes',
#    'position': 'F-C',
#    'height': '6-9',
#    'weight': '235',
#    'jersey_number': '22',
#    'college': 'Bowling Green',
#    'country': 'USA',
#    'draft_year': 2015,
#    'draft_round': 2,
#    'draft_number': 37,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Holmes (shoulder) has been ruled out for Sunday's game against Miami.",
#   'status': 'Out'},
#  {'player': {'id': 666848,
#    'first_name': 'Jordan',
#    'last_name': 'Poole',
#    'position': 'G',
#    'height': '6-4',
#    'weight': '194',
#    'jersey_number': '13',
#    'college': 'Michigan',
#    'country': 'USA',
#    'draft_year': 2019,
#    'draft_round': 1,
#    'draft_number': 28,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Poole (elbow) has been ruled out for Sunday's game against the Heat.",
#   'status': 'Out'},
#  {'player': {'id': 3547302,
#    'first_name': 'Anthony',
#    'last_name': 'Gill',
#    'position': 'F',
#    'height': '6-8',
#    'weight': '230',
#    'jersey_number': '16',
#    'college': 'Virginia',
#    'country': 'USA',
#    'draft_year': None,
#    'draft_round': None,
#    'draft_number': None,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': "Apr 12: Gill (hamstring) has been ruled out for Sunday's game against Miami.",
#   'status': 'Out'},
#  {'player': {'id': 315,
#    'first_name': 'Khris',
#    'last_name': 'Middleton',
#    'position': 'F',
#    'height': '6-7',
#    'weight': '222',
#    'jersey_number': '32',
#    'college': 'Texas A&M',
#    'country': 'USA',
#    'draft_year': 2012,
#    'draft_round': 2,
#    'draft_number': 39,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': 'Apr 11: Head coach Brian Keefe said Friday that Middleton (knee) is unlikely to return this season, Varun Shankar of The Washington Post reports.',
#   'status': 'Out'},
#  {'player': {'id': 17896045,
#    'first_name': 'Corey',
#    'last_name': 'Kispert',
#    'position': 'F',
#    'height': '6-6',
#    'weight': '224',
#    'jersey_number': '24',
#    'college': 'Gonzaga',
#    'country': 'USA',
#    'draft_year': 2021,
#    'draft_round': 1,
#    'draft_number': 15,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': 'Mar 18: Kispert underwent successful surgery on his left thumb Tuesday and is expected to make a full recovery and be ready for the start of next season.',
#   'status': 'Out'},
#  {'player': {'id': 56677844,
#    'first_name': 'Bilal',
#    'last_name': 'Coulibaly',
#    'position': 'G',
#    'height': '6-8',
#    'weight': '195',
#    'jersey_number': '0',
#    'college': 'Metropolitans 92',
#    'country': 'France',
#    'draft_year': 2023,
#    'draft_round': 1,
#    'draft_number': 7,
#    'team_id': 30},
#   'return_date': 'Oct 1',
#   'description': 'Mar 13: The Wizards announced Thursday that Coulibaly will be out approximately 4-6 weeks with a right hamstring injury, Michael Scotto of USA Today reports.',
#   'status': 'Out'},
#  ...]

# %%
injuries_df = pd.json_normalize(all_data)

# %%
injuries_df['created_at']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'created_at'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 injuries_df['created_at']
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'created_at'
